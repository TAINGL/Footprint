# %% [markdown]
# # World Happiness Report 2016

# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set()
import matplotlib.pyplot as plt
import folium

# %% [markdown]
# - https://www.weforum.org/agenda/2016/07/greenest-happiest-country-in-the-world/
# - https://medium.com/age-of-awareness/ecological-footprint-earth-overshoot-day-and-the-happy-planet-index-8ff5fc19af06

# %% [markdown]
# ## Chargement des données

# %% [markdown]
# #### Les différents types de fichiers:
# - Happy Planet Index: http://happyplanetindex.org/
# - Kaggle - World Happiness 2016: https://www.kaggle.com/unsdsn/world-happiness/version/1

# %%
WH2015 = pd.read_csv('/Users/Johanna/Documents/SIMPLON/CHEF DOEUVRE/SOURCE/world-happiness/world-happiness-report-2015.csv')
WH2016 = pd.read_csv('/Users/Johanna/Documents/SIMPLON/CHEF DOEUVRE/SOURCE/world-happiness/world-happiness-report-2016.csv')
WH2017 = pd.read_csv('/Users/Johanna/Documents/SIMPLON/CHEF DOEUVRE/SOURCE/world-happiness/world-happiness-report-2017.csv')
WH2018 = pd.read_csv('/Users/Johanna/Documents/SIMPLON/CHEF DOEUVRE/SOURCE/world-happiness/world-happiness-report-2018.csv')

# %% [markdown]
# #### Kaggle - World Happiness 2015

# %%
WH2015.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %% [markdown]
# #### Kaggle - World Happiness 2016

# %%
WH2016.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# ...

# %% [markdown]
# #### Kaggle - World Happiness 2017

# %%
WH2017.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# ...

# %% [markdown]
# #### Kaggle - World Happiness 2018

# %%
WH2018.head()
# Out:
#    Rank      Country  Score  GDP_Per_Capita  Social_Support  \
# 0     1      Finland  7.632           1.305           1.592
# 1     2       Norway  7.594           1.456           1.582
# 2     3      Denmark  7.555           1.351           1.590
# 3     4      Iceland  7.495           1.343           1.644
# 4     5  Switzerland  7.487           1.420           1.549
#
#    Healthy_Life_Expectancy  Freedom_To_Make_Life_Choices  Generosity  \
# 0                    0.874                         0.681       0.192
# 1                    0.861                         0.686       0.286
# 2                    0.868                         0.683       0.284
# 3                    0.914                         0.677       0.353
# 4                    0.927                         0.660       0.256
#
#    Perceptions_Of_Corruption  Residual
# 0                      0.393     2.988
# 1                      0.340     2.723
# 2                      0.408     2.779
# ...

# %% [markdown]
# ## Analyse des données

# %% [markdown]
# - Supprimer les données superflues et les valeurs aberrantes
# - Ajouter les valeurs manquantes
# - Adapter les données à une structure standard
# - Masquer les données privées ou sensibles

# %% [markdown]
# #### Descriptif / Informations des colonnes
# - WH2015: World Happiness 2015

# %%
WH2015.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
WH2015.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
# REORGANISATION DE L'ORDRE DES COLONNES
WH2017 = WH2017[['Country', 'Happiness.Rank', 'Happiness.Score', 'Economy..GDP.per.Capita.', 'Family', 'Health..Life.Expectancy.', 'Freedom', 'Trust..Government.Corruption.', 'Generosity', 'Dystopia.Residual'  ]]
WH2017
# Out:
#                       Country  Happiness.Rank  Happiness.Score  \
# 0                      Norway               1            7.537
# 1                     Denmark               2            7.522
# 2                     Iceland               3            7.504
# 3                 Switzerland               4            7.494
# 4                     Finland               5            7.469
# ..                        ...             ...              ...
# 150                    Rwanda             151            3.471
# 151                     Syria             152            3.462
# 152                  Tanzania             153            3.349
# 153                   Burundi             154            2.905
# 154  Central African Republic             155            2.693
#
#      Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                    1.616463  1.533524                  0.796667  0.635423
# ...

# %%
WH2018.head()
WH2018 = WH2018[['Country', 'Rank', 'Score', 'GDP_Per_Capita', 'Social_Support', 'Healthy_Life_Expectancy', 'Freedom_To_Make_Life_Choices', 'Perceptions_Of_Corruption', 'Generosity', 'Residual'  ]]
WH2018
# Out:
#                       Country  Rank  Score  GDP_Per_Capita  Social_Support  \
# 0                     Finland     1  7.632           1.305           1.592
# 1                      Norway     2  7.594           1.456           1.582
# 2                     Denmark     3  7.555           1.351           1.590
# 3                     Iceland     4  7.495           1.343           1.644
# 4                 Switzerland     5  7.487           1.420           1.549
# ..                        ...   ...    ...             ...             ...
# 151                     Yemen   152  3.355           0.442           1.073
# 152                  Tanzania   153  3.303           0.455           0.991
# 153               South Sudan   154  3.254           0.337           0.608
# 154  Central African Republic   155  3.083           0.024           0.000
# 155                   Burundi   156  2.905           0.091           0.627
#
#      Healthy_Life_Expectancy  Freedom_To_Make_Life_Choices  \
# ...

# %%
# RENAME COLUMN DATAFRAMES:
WH2015.rename(columns={'Happiness Rank':'Happiness_Rank',
                       'Happiness Score':'Happiness_Score',
                       'Economy (GDP per Capita)':'GDP',
                       'Health (Life Expectancy)':'Health',
                       'Trust (Government Corruption)': 'Trust',
                       'Dystopia Residual': 'Dystopia_Residual'
                      }, inplace=True)
WH2015
# Out:
#          Country                           Region  Happiness_Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness_Score  Standard Error      GDP   Family   Health  Freedom  \
# 0              7.587         0.03411  1.39651  1.34951  0.94143  0.66557
# ...

# %%
WH2016.rename(columns={'Happiness Rank':'Happiness_Rank',
                       'Happiness Score':'Happiness_Score',
                       'Economy (GDP per Capita)':'GDP',
                       'Health (Life Expectancy)':'Health',
                       'Trust (Government Corruption)': 'Trust',
                       'Dystopia Residual': 'Dystopia_Residual'
                      }, inplace=True)
WH2016
# Out:
#          Country                           Region  Happiness_Rank  \
# 0        Denmark                   Western Europe               1
# 1    Switzerland                   Western Europe               2
# 2        Iceland                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4        Finland                   Western Europe               5
# ..           ...                              ...             ...
# 152        Benin               Sub-Saharan Africa             153
# 153  Afghanistan                    Southern Asia             154
# 154         Togo               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
#
#      Happiness_Score  Lower Confidence Interval  Upper Confidence Interval  \
# 0              7.526                      7.460                      7.592
# ...

# %%
WH2017.rename(columns={'Happiness.Rank':'Happiness_Rank',
                       'Happiness.Score':'Happiness_Score',
                       'Economy..GDP.per.Capita.':'GDP',
                       'Health..Life.Expectancy.':'Health',
                       'Trust..Government.Corruption.': 'Trust',
                       'Dystopia.Residual': 'Dystopia_Residual'
                      }, inplace=True)
WH2017
# Out:
#                       Country  Happiness_Rank  Happiness_Score       GDP  \
# 0                      Norway               1            7.537  1.616463
# 1                     Denmark               2            7.522  1.482383
# 2                     Iceland               3            7.504  1.480633
# 3                 Switzerland               4            7.494  1.564980
# 4                     Finland               5            7.469  1.443572
# ..                        ...             ...              ...       ...
# 150                    Rwanda             151            3.471  0.368746
# 151                     Syria             152            3.462  0.777153
# 152                  Tanzania             153            3.349  0.511136
# 153                   Burundi             154            2.905  0.091623
# 154  Central African Republic             155            2.693  0.000000
#
#        Family    Health   Freedom     Trust  Generosity  Dystopia_Residual
# ...

# %%
WH2018
# Out:
#                       Country  Rank  Score  GDP_Per_Capita  Social_Support  \
# 0                     Finland     1  7.632           1.305           1.592
# 1                      Norway     2  7.594           1.456           1.582
# 2                     Denmark     3  7.555           1.351           1.590
# 3                     Iceland     4  7.495           1.343           1.644
# 4                 Switzerland     5  7.487           1.420           1.549
# ..                        ...   ...    ...             ...             ...
# 151                     Yemen   152  3.355           0.442           1.073
# 152                  Tanzania   153  3.303           0.455           0.991
# 153               South Sudan   154  3.254           0.337           0.608
# 154  Central African Republic   155  3.083           0.024           0.000
# 155                   Burundi   156  2.905           0.091           0.627
#
#      Healthy_Life_Expectancy  Freedom_To_Make_Life_Choices  \
# ...

# %%
WH2018.rename(columns={'Rank':'Happiness_Rank',
                       'Score':'Happiness_Score',
                       'GDP_Per_Capita':'GDP',
                       'Social_Support': 'Family',
                       'Healthy_Life_Expectancy':'Health',
                       'Freedom_To_Make_Life_Choices':'Freedom',
                       'Perceptions_Of_Corruption': 'Trust',
                       'Residual': 'Dystopia_Residual'
                      }, inplace=True)
WH2018
# Out:
#                       Country  Happiness_Rank  Happiness_Score    GDP  Family  \
# 0                     Finland               1            7.632  1.305   1.592
# 1                      Norway               2            7.594  1.456   1.582
# 2                     Denmark               3            7.555  1.351   1.590
# 3                     Iceland               4            7.495  1.343   1.644
# 4                 Switzerland               5            7.487  1.420   1.549
# ..                        ...             ...              ...    ...     ...
# 151                     Yemen             152            3.355  0.442   1.073
# 152                  Tanzania             153            3.303  0.455   0.991
# 153               South Sudan             154            3.254  0.337   0.608
# 154  Central African Republic             155            3.083  0.024   0.000
# 155                   Burundi             156            2.905  0.091   0.627
#
# ...

# %%
# SUPPRIMER DES COLONNES:
WH2015 = WH2015.drop(['Region', 'Standard Error','GDP' ], axis = 1)
WH2016 = WH2016.drop(['Region','Lower Confidence Interval', 'Upper Confidence Interval', 'GDP',  ], axis = 1)
WH2017 = WH2017.drop(['GDP'], axis = 1)
WH2018 = WH2018.drop(['GDP'], axis = 1)

# %%
# NORMALISATION DES INFORMATIONS PAR COLONNES: Country
WH2015_country = WH2015["Country"].unique()
WH2016_country = WH2015["Country"].unique()
WH2017_country = WH2015["Country"].unique()
WH2018_country = WH2015["Country"].unique()

sorted(WH2015_country)
sorted(WH2016_country)
sorted(WH2017_country)
sorted(WH2018_country)
# Out:
# ['Afghanistan',
#  'Albania',
#  'Algeria',
#  'Angola',
#  'Argentina',
#  'Armenia',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahrain',
#  'Bangladesh',
#  'Belarus',
#  'Belgium',
#  'Benin',
#  'Bhutan',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Brazil',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burundi',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Central African Republic',
#  'Chad',
#  'Chile',
#  'China',
#  'Colombia',
#  'Comoros',
#  'Congo (Brazzaville)',
#  'Congo (Kinshasa)',
#  'Costa Rica',
#  'Croatia',
#  'Cyprus',
#  'Czech Republic',
#  'Denmark',
#  'Djibouti',
#  'Dominican Republic',
#  'Ecuador',
#  'Egypt',
#  'El Salvador',
#  'Estonia',
#  'Ethiopia',
#  'Finland',
#  'France',
#  'Gabon',
#  'Georgia',
#  'Germany',
#  'Ghana',
#  'Greece',
#  'Guatemala',
#  'Guinea',
#  'Haiti',
#  'Honduras',
#  'Hong Kong',
#  'Hungary',
#  'Iceland',
#  'India',
#  'Indonesia',
#  'Iran',
#  'Iraq',
#  'Ireland',
#  'Israel',
#  'Italy',
# ...

# %%
len(sorted(WH2016_country))
# Out:
# 158

# %%
# COMPARE TWO LISTS AND RETURN MATCHES:
# SAME SAME
country_matches = set(WH2015_country) & set(WH2016_country) & set(WH2017_country) & set(WH2018_country)
country_matches = list(sorted(country_matches))
len(country_matches)
# Out:
# 158

# %%
# ADD COLUMNS TO DATAFRAME: Years
WH2015['Years'] = 2015 
WH2016['Years'] = 2016
WH2017['Years'] = 2017
WH2018['Years'] = 2018
WH2015
# Out:
#          Country  Happiness_Rank  Happiness_Score   Family   Health  Freedom  \
# 0    Switzerland               1            7.587  1.34951  0.94143  0.66557
# 1        Iceland               2            7.561  1.40223  0.94784  0.62877
# 2        Denmark               3            7.527  1.36058  0.87464  0.64938
# 3         Norway               4            7.522  1.33095  0.88521  0.66973
# 4         Canada               5            7.427  1.32261  0.90563  0.63297
# ..           ...             ...              ...      ...      ...      ...
# 153       Rwanda             154            3.465  0.77370  0.42864  0.59201
# 154        Benin             155            3.340  0.35386  0.31910  0.48450
# 155        Syria             156            3.006  0.47489  0.72193  0.15684
# 156      Burundi             157            2.905  0.41587  0.22396  0.11850
# 157         Togo             158            2.839  0.13995  0.28443  0.36453
#
# ...

# %%
WH2015 = WH2015.reindex(columns = ['Country', 'Years', 'Happiness_Rank', 'Happiness_Score', 'Family', 'Health', 'Freedom', 'Trust', 'Generosity', 'Dystopia_Residual'])
WH2016 = WH2016.reindex(columns = ['Country', 'Years', 'Happiness_Rank', 'Happiness_Score', 'Family', 'Health', 'Freedom', 'Trust', 'Generosity', 'Dystopia_Residual'])
WH2017 = WH2017.reindex(columns = ['Country', 'Years', 'Happiness_Rank', 'Happiness_Score', 'Family', 'Health', 'Freedom', 'Trust', 'Generosity', 'Dystopia_Residual'])
WH2018 = WH2018.reindex(columns = ['Country', 'Years', 'Happiness_Rank', 'Happiness_Score', 'Family', 'Health', 'Freedom', 'Trust', 'Generosity', 'Dystopia_Residual'])

# %%
# https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html
WH = [WH2015, WH2016, WH2017, WH2018]
WH_all = pd.concat(WH)

# %%
WH_all
# Out:
#                       Country  Years  Happiness_Rank  Happiness_Score  \
# 0                 Switzerland   2015               1            7.587
# 1                     Iceland   2015               2            7.561
# 2                     Denmark   2015               3            7.527
# 3                      Norway   2015               4            7.522
# 4                      Canada   2015               5            7.427
# ..                        ...    ...             ...              ...
# 151                     Yemen   2018             152            3.355
# 152                  Tanzania   2018             153            3.303
# 153               South Sudan   2018             154            3.254
# 154  Central African Republic   2018             155            3.083
# 155                   Burundi   2018             156            2.905
#
#       Family   Health  Freedom    Trust  Generosity  Dystopia_Residual
# ...

# %%
WH_all.dtypes
# Out:
# Country               object
# Years                  int64
# Happiness_Rank         int64
# Happiness_Score      float64
# Family               float64
# Health               float64
# Freedom              float64
# Trust                float64
# Generosity           float64
# Dystopia_Residual    float64
# dtype: object

# %%
WH_all.to_csv('WH_all.csv')

# %%
# connecter à MySQL  
# mysql+pymysql://<username>:<password>@<host>/<dbname>[?<options>]
from sqlalchemy import create_engine

engine = create_engine("mysql+pymysql://root:password.?19@127.0.0.1/footprint?host=127.0.0.1?port=3306") 
conn = engine.connect() 
print('connected')
# Out:
# connected

# %%
WH_all
# Out:
#                       Country  Years  Happiness_Rank  Happiness_Score  \
# 0                 Switzerland   2015               1            7.587
# 1                     Iceland   2015               2            7.561
# 2                     Denmark   2015               3            7.527
# 3                      Norway   2015               4            7.522
# 4                      Canada   2015               5            7.427
# ..                        ...    ...             ...              ...
# 151                     Yemen   2018             152            3.355
# 152                  Tanzania   2018             153            3.303
# 153               South Sudan   2018             154            3.254
# 154  Central African Republic   2018             155            3.083
# 155                   Burundi   2018             156            2.905
#
#       Family   Health  Freedom    Trust  Generosity  Dystopia_Residual
# ...

# %%
CREATE TABLE IF NOT EXISTS WH (
	Country VARCHAR (48),
    Years YEARS (4),
    Happiness_Rank INT,
    Happiness_Score FLOAT,
    Family FLOAT,
    Health FLOAT,
    Freedom FLOAT,
    Trust FLOAT,
    Generosity FLOAT,
    Dystopia_Residual FLOAT,
    PRIMARY KEY AUTO_INCREMENT(Country, Years)
);
# Out:
#   File "<ipython-input-28-481d603ab3bb>", line 1
#     CREATE TABLE IF NOT EXISTS WH (
#                ^
# SyntaxError: invalid syntax

# %%
ALTER TABLE WH 
	MODIFY Country VARCHAR (48),
    MODIFY Years YEAR (4),
    MODIFY Happiness_Rank INT,
    MODIFY Happiness_Score FLOAT,
    MODIFY Family FLOAT,
    MODIFY Health FLOAT,
    MODIFY Freedom FLOAT,
    MODIFY Trust FLOAT,
    MODIFY Generosity FLOAT,
    MODIFY Dystopia_Residual FLOAT,
    ADD PRIMARY KEY (Country, Years)
;
# Out:
#   File "<tokenize>", line 3
#     MODIFY Years YEAR (4),
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
WH_all.to_sql('WH', conn, if_exists='replace', index = False)

# %%
table_WH_1 = 'CREATE TABLE IF NOT EXISTS WH (Country VARCHAR (48), Years YEAR (4), Happiness_Rank INT, Happiness_Score FLOAT, Family FLOAT, Health FLOAT, Freedom FLOAT, Trust FLOAT, Generosity FLOAT, Dystopia_Residual FLOAT, PRIMARY KEY AUTO_INCREMENT(Country, years));'

# %%
table_WH = 'ALTER TABLE WH MODIFY Country VARCHAR (48), MODIFY Years YEAR (4), MODIFY Happiness_Rank INT, MODIFY Happiness_Score FLOAT, MODIFY Family FLOAT, MODIFY Health FLOAT, MODIFY Freedom FLOAT, MODIFY Trust FLOAT, MODIFY Generosity FLOAT, MODIFY Dystopia_Residual FLOAT, ADD PRIMARY KEY (Country, Years);'

# %%
import pymysql
import pymysql.cursors

# %%
# create connection
connection = pymysql.connect(host='127.0.0.1',
                             user='root',
                             password='password.?19')

print('Connected to DB: {}'.format(connection))
# Out:
# Connected to DB: <pymysql.connections.Connection object at 0x11d98f320>

# %%
# Create cursor and execute Load SQL
cursor = connection.cursor()

# %%
# Connect DB
cursor.execute('USE footprint;')
# Out:
# 0

# %%
# importer un DF dans une table
WH_all.to_sql('WH', conn, if_exists='replace', index = False)

# %%
cursor.execute('ALTER TABLE WH MODIFY Country VARCHAR (48), MODIFY Years YEAR (4), MODIFY Happiness_Rank INT, MODIFY Happiness_Score FLOAT, MODIFY Family FLOAT, MODIFY Health FLOAT, MODIFY Freedom FLOAT, MODIFY Trust FLOAT, MODIFY Generosity FLOAT, MODIFY Dystopia_Residual FLOAT, ADD PRIMARY KEY (Country, Years);')
# Out:
# 626

# %%
# Execute Query
cursor.execute("SELECT * from WH")

# Fetch the records
result = cursor.fetchall()

for i in result:
    print(i)

# Close the connection
connection.close()
# Out:
# ('Afghanistan', 2015, 153, 3.575, 0.30285, 0.30335, 0.23414, 0.09719, 0.3651, 1.9521)
# ('Afghanistan', 2016, 154, 3.36, 0.11037, 0.17344, 0.1643, 0.07112, 0.31268, 2.14558)
# ('Afghanistan', 2017, 141, 3.794, 0.581543, 0.180747, 0.10618, 0.0611578, 0.311871, 2.1508)
# ('Afghanistan', 2018, 145, 3.632, 0.537, 0.255, 0.085, 0.036, 0.191, 2.232)
# ('Albania', 2015, 95, 4.959, 0.80434, 0.81325, 0.35733, 0.06413, 0.14272, 1.89894)
# ('Albania', 2016, 109, 4.655, 0.50163, 0.73007, 0.31866, 0.05301, 0.1684, 1.92816)
# ('Albania', 2017, 109, 4.644, 0.803685, 0.73116, 0.381499, 0.0398642, 0.201313, 1.49044)
# ('Albania', 2018, 112, 4.586, 0.817, 0.79, 0.419, 0.032, 0.149, 1.495)
# ('Algeria', 2015, 68, 5.605, 1.07772, 0.61766, 0.28579, 0.17383, 0.07822, 2.43209)
# ('Algeria', 2016, 38, 6.355, 0.83309, 0.61804, 0.21006, 0.16157, 0.07044, 3.40904)
# ('Algeria', 2017, 53, 5.872, 1.14622, 0.617585, 0.233336, 0.146096, 0.0694366, 2.5676)
# ...
