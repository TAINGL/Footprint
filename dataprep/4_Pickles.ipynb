# %%
import pickle

# %%
#pour enregistrer tes fichiers en pickle: 
def session_save(picke_path, objects):
    pickling_on = open(picke_path,"wb")
    try:
        pickle.dump(objects, pickling_on)
        print("session_save success\n")
    except:
        print("session_save failed\n")
    finally:
        pickling_on.close()

# %%
#pour lire et récuperer un df:
try:
    pickle_off = open("gsSessionM.pickle","rb")
    gsSession = pickle.load(pickle_off)
    pickle_off.close()
except:
    print("il y a eu une erreur avec le pickle")
    pass
# Out:
# il y a eu une erreur avec le pickle

# %%
pickle.load(open('Country_index', 'rb'))
# Out:
#                  Country ISO_3                        UN_region  \
# 0            Afghanistan   AFG                             Asia
# 1                Albania   ALB                           Europe
# 2                Algeria   DZA                           Africa
# 3                 Angola   AGO                           Africa
# 4    Antigua and Barbuda   ATG  Latin America and the Caribbean
# ..                   ...   ...                              ...
# 177             Viet Nam   VNM                             Asia
# 178                World     W                            World
# 179                Yemen   YEM                             Asia
# 180               Zambia   ZMB                           Africa
# 181             Zimbabwe   ZWE                           Africa
#
#            UN_subregion Data_Quality
# 0         Southern Asia            6
# 1       Southern Europe            6
# 2       Northern Africa            5
# 3         Middle Africa            6
# 4             Caribbean            2
# ..                  ...          ...
# 177  South-Eastern Asia            6
# 178               World          NaN
# 179        Western Asia            5
# 180      Eastern Africa            6
# 181      Eastern Africa            6
#
# [182 rows x 5 columns]

# %%
Economy_info = pickle.load(open('Economy_info', 'rb'))

# %%
Economy_info
# Out:
#      ISO_3  Years      GDP  Population
# 0      ABW   1986      NaN       63000
# 1      ABW   1987      NaN       62000
# 2      ABW   1988      NaN       61000
# 3      ABW   1989      NaN       61000
# 4      ABW   1990      NaN       62000
# ...    ...    ...      ...         ...
# 8602   ZWE   2011  813.834    14256000
# 8603   ZWE   2012  913.531    14565000
# 8604   ZWE   2013  942.039    14898000
# 8605   ZWE   2014  939.780    15246000
# 8606   ZWE   2016  865.910    13720000
#
# [8607 rows x 4 columns]

# %%
import pandas as pd
